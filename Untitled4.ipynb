# %% [markdown]
# <a href="https://colab.research.google.com/github/mdrabiyab-netizen/PRODIGY_ML_03/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Assuming 'zip_filename' (which is actually the image filename) holds the path to the uploaded image
image_path = zip_filename

try:
    img = Image.open(image_path)
    plt.imshow(img)
    plt.title(f'Uploaded Image: {os.path.basename(image_path)}')
    plt.axis('off') # Hide axes ticks
    plt.show()
except FileNotFoundError:
    print(f"Error: The file '{image_path}' was not found.")
except Exception as e:
    print(f"An error occurred while displaying the image: {e}")
